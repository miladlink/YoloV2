# %%
import cfg
from visualize import *

# %%
predict (
    model = cfg.MODEL,
    conf_thresh = 0.4,
    nms_thresh = 0.4,
    img_path = 'images/dog.jpg',
    class_names = cfg.CLASS_NAMES,
    device = cfg.DEVICE,
    save_to = 'preds/dog.jpg'
    )
# Out:
# Prediction took 502.87843 ms.
# truck     : 0.381391
# dog       : 0.225122
# boat      : 0.132441
# motorcycle: 0.091847
# save plot results to preds/dog.jpg
# <PIL.Image.Image image mode=RGB size=768x576 at 0x7FC5B329F250>

# %%
predict_cv2 (
    model = cfg.MODEL,
    conf_thresh = 0.4,
    nms_thresh = 0.4,
    img_path = 'images/dog.jpg',
    class_names = cfg.CLASS_NAMES,
    device = cfg.DEVICE,
    save_to = 'preds/dogcv2.jpg'
    )
# Out:
# Prediction took 544.49987 ms.
# truck     : 0.416721
# dog       : 0.118781
# motorcycle: 0.071613
# save plot results to preds/dogcv2.jpg

# %%
predict (
    model = cfg.MODEL,
    conf_thresh = 0.4,
    nms_thresh = 0.4,
    img_path = 'images/person.jpg',
    class_names = cfg.CLASS_NAMES,
    device = cfg.DEVICE,
    save_to = 'preds/person.jpg'
    )
# Out:
# Prediction took 471.25721 ms.
# horse     : 0.375917
# person    : 0.357436
# dog       : 0.268418
# save plot results to preds/person.jpg
# <PIL.Image.Image image mode=RGB size=640x424 at 0x7FC5B327DA30>

# %%
predict (
    model = cfg.MODEL,
    conf_thresh = 0.4,
    nms_thresh = 0.4,
    img_path = 'images/horses.jpg',
    class_names = cfg.CLASS_NAMES,
    device = cfg.DEVICE,
    save_to = 'preds/horses.jpg'
    )
# Out:
# Prediction took 442.29650 ms.
# horse     : 0.099612
# zebra     : 0.037328
# horse     : 0.032356
# horse     : 0.003577
# save plot results to preds/horses.jpg
# <PIL.Image.Image image mode=RGB size=773x512 at 0x7FC5B39F6550>

# %%
predict (
    model = cfg.MODEL,
    conf_thresh = 0.4,
    nms_thresh = 0.4,
    img_path = 'images/giraffe.jpg',
    class_names = cfg.CLASS_NAMES,
    device = cfg.DEVICE,
    save_to = 'preds/giraffe.jpg'
    )
# Out:
# Prediction took 503.70884 ms.
# zebra     : 0.108143
# giraffe   : 0.048326
# save plot results to preds/giraffe.jpg
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FC5B329F3A0>
